# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("https://raw.githubusercontent.com/kushalhallikar-spec/Phoneprice-dataset/refs/heads/main/Cellphone.csv")

# %%
data.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
data.shape
# Out:
# (161, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %%
data.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# ...

# %%
data["Price"].idxmin()
# Out:
# 149

# %%
data.iloc[150]
# Out:
# Product_id       826.000
# Price            614.000
# Sale            2171.000
# weight            69.800
# resoloution        1.400
# ppi              129.000
# cpu core           0.000
# cpu freq           0.000
# internal mem       0.000
# ram                0.004
# RearCam            0.000
# Front_Cam          0.000
# battery          800.000
# thickness         14.100
# Name: 150, dtype: float64

# %%
data["Price"].idxmax()
# Out:
# 152

# %%
data.iloc[152]
# Out:
# Product_id       290.00
# Price           4361.00
# Sale            3248.00
# weight           238.00
# resoloution        5.70
# ppi              515.00
# cpu core           8.00
# cpu freq           1.95
# internal mem     128.00
# ram                6.00
# RearCam           12.00
# Front_Cam          8.00
# battery         7000.00
# thickness          7.40
# Name: 152, dtype: float64

# %%
lowestpriceid= int(data.iloc[149][0])
highestpriceid=int(data.iloc[152][0])
# Out:
# /tmp/ipython-input-670408387.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lowestpriceid= int(data.iloc[149][0])
# /tmp/ipython-input-670408387.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highestpriceid=int(data.iloc[152][0])

# %%
print("Product id of lowest price cellphone is : " , int(lowestpriceid))
print("Product id of highest price cellphone is : ", int(highestpriceid))
# Out:
# Product id of lowest price cellphone is :  826
# Product id of highest price cellphone is :  290

# %%
data.columns
# Out:
# Index(['Product_id', 'Price', 'Sale', 'weight', 'resoloution', 'ppi',
#        'cpu core', 'cpu freq', 'internal mem', 'ram', 'RearCam', 'Front_Cam',
#        'battery', 'thickness'],
#       dtype='object')

# %%
data = data[['Price', 'weight', 'resoloution', 'ppi',
       'cpu core', 'internal mem', 'ram', 'RearCam', 'Front_Cam',
       'battery', 'thickness']]

# %%
data.columns
# Out:
# Index(['Price', 'weight', 'resoloution', 'ppi', 'cpu core', 'internal mem',
#        'ram', 'RearCam', 'Front_Cam', 'battery', 'thickness'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# np.int64(78)

# %%
data.drop_duplicates(inplace = True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum()
# Out:
# Price           0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
data.corr()["Price"].sort_values(ascending =False)
# Out:
# Price           1.000000
# ram             0.896040
# ppi             0.814855
# internal mem    0.778957
# RearCam         0.740738
# cpu core        0.688402
# Front_Cam       0.674465
# battery         0.558053
# resoloution     0.403869
# weight          0.143802
# thickness      -0.709908
# Name: Price, dtype: float64

# %%
sns.heatmap(data.corr(),annot = True, cmap ="rainbow")
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
colorsforx= ["Red", "Green","Black", "Purple", "Yellow", "Red", "Green", "Black", "Purple", "Yellow", "Red"]
colorchanger=0

# %%
for i in data.columns[:-1]:
  sns.scatterplot(data = data , x = i, y="Price", color = colorsforx[colorchanger])
  plt.show()
  colorchanger +=1
